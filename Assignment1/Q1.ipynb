# %%
import nltk
from nltk.corpus import gutenberg

# %%
all_files = gutenberg.fileids() # Get all the files from Gutenberg
print('Output 1.\n', 'Here are all the files in gutenberg:\n', '\n'.join(all_files))
# Out:
# Output 1.
#  Here are all the files in gutenberg:
#  austen-emma.txt
# austen-persuasion.txt
# austen-sense.txt
# bible-kjv.txt
# blake-poems.txt
# bryant-stories.txt
# burgess-busterbrown.txt
# carroll-alice.txt
# chesterton-ball.txt
# chesterton-brown.txt
# chesterton-thursday.txt
# edgeworth-parents.txt
# melville-moby_dick.txt
# milton-paradise.txt
# shakespeare-caesar.txt
# shakespeare-hamlet.txt
# shakespeare-macbeth.txt
# whitman-leaves.txt

# %%
words_austen = gutenberg.words('austen-persuasion.txt')
words_austen_unique = set(gutenberg.words('austen-persuasion.txt'))

def calculate_words(file):
    number_of_words = 0
    for word in file:
        number_of_words += 1
    return number_of_words

print('Output 2.\n', 'There are', calculate_words(words_austen), 'words in the file \'austen-persuasion.txt\', and',
      calculate_words(words_austen_unique), 'unique words.')
# Out:
# Output 2.
#  There are 98171 words in the file 'austen-persuasion.txt', and 6132 unique words.

# %%
words_austen = gutenberg.words('austen-persuasion.txt')

word_freq = {}

def calculate_freq(file):
    for word in file:
        if word in word_freq:
            word_freq[word] += 1
        else:
            word_freq[word] = 1
    return word_freq

def sort(dic):
    import operator
    sorted_dic = sorted(dic.items(),key = operator.itemgetter(1),reverse=True) # Sort the dic by the values
    return sorted_dic # A list of tuples sorted by the second element in each tuple

print('Output 3.\n Here are the frequency for each words:\n',calculate_freq(words_austen))
# Out:
# Output 3.
#  Here are the frequency for each words:
#  {')': 25, 'bedroom': 2, 'aid': 2, 'robbing': 1, 'direction': 11, 'kindness': 15, 'wholly': 2, 'multiply': 1, 'glance': 14, 'belong': 4, 'message': 3, 'All': 13, 'else': 27, 'unexceptionable': 1, 'assured': 5, 'assurances': 1, 'floor': 2, 'gouty': 2, 'treading': 1, 'interest': 43, 'recoverable': 1, 'shooting': 5, 'slowly': 1, 'unpleasant': 4, 'efforts': 2, 'fully': 14, 'injury': 5, 'plaster': 1, 'respective': 1, 'glowing': 3, 'testify': 1, 'consequently': 8, 'perceiving': 1, 'guilt': 1, 'pitiable': 1, 'Like': 1, 'overheard': 1, 'bid': 3, 'dashing': 1, 'pensive': 2, 'feared': 6, 'hinting': 1, 'fifteen': 3, 'thoughts': 9, 'supposition': 3, 'barely': 1, 'presently': 4, 'land': 2, 'indicate': 1, 'kicking': 1, 'subjects': 9, 'Market': 1, 'fearing': 4, 'thoughtful': 3, 'papa': 6, 'sudden': 7, 'Where': 5, 'Believe': 1, 'apparently': 6, 'bathing': 1, 'nothings': 1, 'Which': 1, 'politicians': 1, 'selves': 1, 'unreasonably': 1, 'equalling': 1, 'closet': 1, 'pen': 5, 'Somersetshire': 4, 'nerves': 9, 'South': 1, 'spacious': 1, 'paltry': 1, 'a': 1529, 'ashore': 2, 'farmer': 2, 'between': 53, 'irritation': 2, 'Grappler': 3, 'thickest': 1, 'vexation': 2, 'Lady': 191, 'preferring': 3, 'accessions': 1, 'God': 9, 'struggle': 7, 'Portsmouth': 3, 'less': 30, 'relieve': 1, 'obstinate': 1, 'furniture': 8, 'professions': 3, 'escaped': 4, 'clergyman': 4, 'adopted': 3, 'misconceived': 1, 'utmost': 3, 'alive': 4, '.--': 1, 'parliaments': 1, 'affords': 1, 'join': 10, 'true': 21, 'sing': 1, 'reseated': 1, 'abilities': 3, 'forbid': 1, 'wind': 4, 'Strangers': 1, 'propose': 4, 'rupture': 1, 'esteemed': 2, 'parcel': 2, '?\'"': 1, 'hear': 38, 'Marmion': 1, 'Viscountess': 4, 'home': 83, ".'": 7, 'inn': 13, 'Their': 20, 'streets': 6, 'obeyed': 2, 'Indeed': 11, 'possessing': 1, 'conscious': 7, 'toys': 1, 'comprehensive': 2, 'bodily': 2, '12': 1, 'flagrant': 1, 'reverted': 2, 'harmony': 1, 'integrity': 1, 'transgressions': 1, 'couple': 5, 'Happily': 1, 'entertain': 2, 'Quit': 1, 'retired': 3, 'equivalent': 1, 'deficiency': 1, 'unutterable': 1, 'world': 36, 'measures': 4, 'conceived': 3, 'escaping': 1, 'energy': 1, 'immethodical': 1, 'acknowledgements': 1, 'descend': 1, 'breakfast': 13, 'concerned': 7, 'windows': 3, 'suspicion': 4, 'Man': 1, 'shifted': 1, 'disposed': 18, 'evade': 1, 'discomfited': 1, 'Finis': 1, 'consciousness': 14, 'legible': 1, 'parental': 1, 'disinclination': 1, 'riotous': 1, 'longed': 4, 'sway': 1, 'pretty': 27, 'prejudice': 2, 'wearisome': 1, 'convenient': 4, 'refuse': 2, 'comprehending': 2, 'pin': 2, 'when': 196, 'misconduct': 1, 'leading': 5, 'Pity': 1, 'captiously': 1, 'instrument': 2, 'attended': 6, 'ideas': 10, 'rationality': 1, 'incomprehensible': 1, 'retentive': 1, 'England': 6, 'reluctant': 2, 'dinners': 3, 'inexpensive': 1, 'happiest': 6, 'yes': 14, 'mother': 42, 'age': 11, 'unhappy': 4, 'itself': 13, 'cease': 3, 'thought': 90, 'enjoyed': 3, 'flatter': 2, 'disappointment': 4, 'courting': 1, 'putting': 11, 'nights': 2, 'pray': 3, 'surveyor': 1, 'approved': 2, 'alienations': 1, 'speculate': 1, 'unnatural': 1, 'personage': 1, 'conjecture': 1, 'equals': 1, 'guarded': 1, '3': 1, 'grieving': 4, 'duties': 4, 'get': 35, 'Asp': 6, 'conviction': 8, 'apprehensions': 3, 'devise': 1, 'vestibule': 1, 'spite': 11, 'prudent': 3, 'whispers': 1, 'overtures': 1, 'reconciliation': 5, 'furnish': 3, 'large': 19, 'persons': 9, 'astray': 1, 'Sarah': 2, 'speaking': 21, 'banish': 1, 'remarkable': 4, 'red': 2, 'omitted': 2, 'Depend': 4, 'unsisterly': 1, 'lieutenant': 2, 'gentleman': 32, 'endowed': 1, 'singing': 3, 'shrubberies': 2, 'just': 65, 'belonging': 5, 'dancing': 7, 'anticipate': 1, 'acre': 1, 'wood': 1, 'advice': 5, 'Very': 9, 'upwards': 1, 'connections': 2, 'Bishop': 1, 'yesterday': 14, 'accidentally': 2, 'sheriff': 1, 'proverbial': 1, 'reproach': 4, 'Ives': 2, 'holidays': 4, 'cried': 47, 'aware': 15, 'slightingly': 1, 'sized': 1, 'sprang': 1, 'bending': 1, 'resolutely': 2, 'amusement': 10, 'verse': 1, 'tenderness': 10, 'indulged': 1, 'Charles': 166,  ...

# %%
print('Output 3.\nThe top-10 and their frequencies:\n',sort(word_freq)[:10])
# Out:
# Output 3.
# The top-10 and their frequencies:
#  [(',', 6750), ('the', 3120), ('to', 2775), ('.', 2741), ('and', 2739), ('of', 2564), ('a', 1529), ('in', 1346), ('was', 1330), (';', 1290)]
